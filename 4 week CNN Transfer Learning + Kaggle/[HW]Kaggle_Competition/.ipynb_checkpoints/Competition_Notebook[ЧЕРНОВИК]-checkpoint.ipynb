# %%
import numpy as np
from numpy import random
from matplotlib import colors, pyplot as plt
# %matplotlib inline
from tqdm.autonotebook import tqdm, trange
from tqdm import tqdm_notebook


import torch
from torcheval.metrics.functional import multiclass_f1_score
from torchmetrics.classification import MulticlassAccuracy
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
from torchvision import datasets, models, transforms
import torch.optim as optim
from torch.optim import lr_scheduler
device = 'cuda' if torch.cuda.is_available() else 'cpu'

import PIL
from PIL import Image
import pickle
from skimage import io
from sklearn.preprocessing import LabelEncoder
from pathlib import Path
from multiprocessing.pool import ThreadPool
import time



# разные режимы датасета
DATA_MODES = ['train', 'val', 'test']
# все изображения будут масштабированы к размеру 224x224 px
RESCALE_SIZE = 224


class SimpsonsDataset(Dataset):
    """
    Датасет с картинками, который паралельно подгружает их из папок
    производит скалирование и превращение в торчевые тензоры
    """
    def __init__(self, files, mode):
        super().__init__()
        # список файлов для загрузки
        self.files = sorted(files) #Принимает в себя файлы
        self.mode = mode # режим работы

        if self.mode not in DATA_MODES: #Проверка на то, корректно ли указан mode
            print(f"{self.mode} is not correct; correct modes: {DATA_MODES}")
            raise NameError

        self.len_ = len(self.files) #Атрибут длины списка файлов(ака размер выборки)

        self.label_encoder = LabelEncoder() # Заводм LabelEncoder как метод класса

        if self.mode != 'test': # Если мы не в режиме val/train, то в labels записываем 
                    # названия папок(они называются как классы персонажей)
            self.labels = [path.parent.name for path in self.files]
            self.label_encoder.fit(self.labels)#Фитим энкодер на наших лейблах,но не меняем пока
            
            # сохраняем натренированый энкодер как label_encoder.pkl
            # 'wb' означает что мы записываем бинарные данные (???)
            with open('label_encoder.pkl', 'wb') as le_dump_file:
                  pickle.dump(self.label_encoder, le_dump_file) 

    def __len__(self):
        return self.len_ #Метод, возвращающий атрибут длины

    def load_sample(self, file):
        image = Image.open(file)
        image.load()
        return image

    def __getitem__(self, index):
        # для преобразования изображений в тензоры PyTorch и нормализации входа
        transform = transforms.Compose([
            transforms.ToTensor(), #Превращает в тензор
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]),
            transforms.RandomHorizontalFlip(p=0.5)
            
        ])
        x = self.load_sample(self.files[index]) #подгружает фотку по индексу
        x = self._prepare_sample(x) #Подгоняет фото под размер 224на224
        x = np.array(x / 255, dtype='float32') # зачем то делим на 225
        x = transform(x) # проводим те трансформации, кот. объявлены ранее
        if self.mode == 'test': #если мы в тестовом режиме, то просто возвращаем x без y
            return x
        else: #если мы в val,train режиме, то 
            label = self.labels[index] #берём лейбл по индексу
            label_id = self.label_encoder.transform([label]) #энкодим его в число
            y = label_id.item()
            return x, y #возвращаем связку объёкт-лейбл

    def _prepare_sample(self, image): #Подгоняет фото под размер 224на224
        image = image.resize((RESCALE_SIZE, RESCALE_SIZE))
        return np.array(image)
    
def imshow(inp, title=None, plt_ax=plt, default=False):
    """Imshow для тензоров"""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt_ax.imshow(inp)
    if title is not None:
        plt_ax.set_title(title)
    plt_ax.grid(False)    
    
    #определим директории с тренировочными и тестовыми файлами
TRAIN_DIR = Path('./train')
TEST_DIR = Path('./testset')

# формируем списки ссылок на фотки
train_val_files = sorted(list(TRAIN_DIR.rglob('*.jpg')))
test_files = sorted(list(TEST_DIR.rglob('*.jpg')))


from sklearn.model_selection import train_test_split
#array лейблов в train_val фотках
train_val_labels = [path.parent.name for path in train_val_files]
# Разбиваем train_val_files на отдельные train и val.Стратификация проходит по train_val_labels
# это по прежнему не тензоры, а просто списки ссылок(без лейблов,тк их вычленим к теле Класса)
train_files, val_files = train_test_split(train_val_files, test_size=0.25, \
                                          stratify=train_val_labels)

#Делаем train и val датасеты, создавая классы, в теле которых уже будет происходить
# Нормализация,приведение в теннзорный вид, создание лейблов(числовых).
train_dataset = SimpsonsDataset(train_files, mode='train')
val_dataset = SimpsonsDataset(val_files, mode='val')

fig, ax = plt.subplots(nrows=3, ncols=3,figsize=(8, 8), \
                        sharey=True, sharex=True)
for fig_x in ax.flatten():
    random_characters = int(np.random.uniform(0,1000))
    im_val, label = val_dataset[random_characters]
    img_label = " ".join(map(lambda x: x.capitalize(),\
                val_dataset.label_encoder.inverse_transform([label])[0].split('_')))
    imshow(im_val.data.cpu(), \
          title=img_label,plt_ax=fig_x)
    
dataset_sizes = {'train':len(train_dataset), 'val':len(val_dataset)}  


# Функция тренировки модели
def training(model, criterion, optimizer, scheduler, num_epochs, batch, losses, metrics, accs):
    
    # Создаём loader,в который засовывем классы.Далее при выплёвывании батча он будет 
    # обращаться к классу через _getitem_ и брать оттуда предобработанные тензоры с их лейблами
    dataloaders = {'train': torch.utils.data.DataLoader(train_dataset, batch_size=batch,
                                              shuffle=True, num_workers=2),
               'val': torch.utils.data.DataLoader(val_dataset, batch_size=batch,
                                              shuffle=True, num_workers=2)}
    
    since = time.time()
    best_model_wts = model.state_dict()
    best_f1 = 0
    best_acc = 0
    
    pbar = trange(num_epochs, desc="Epoch:")
    
    for epoch in pbar:
        for phase in ['train', 'val']:
            #=====Установка режима работы модели в зав-ти от фазы======
            if phase == 'train':
                scheduler.step()
                model.train(True)
            else:
                model.eval() 
            #======Обновление loss и целевых метрик =============
            running_loss = 0.0
            running_f1 = 0
            running_acc = 0
            #======Процесс итерации по батчам ===================
            for data in tqdm(dataloaders[phase], leave=False, desc=f"{phase} iter:"):
                
                batch_x, batch_y = data
                
                if device == 'cuda':
                    batch_x = batch_x.cuda()
                    batch_y = batch_y.cuda()
                else:
                    batch_x, batch_y = batch_x, batch_y
                    
                if phase == "train":
                    optimizer.zero_grad()
                
                if phase == "val":
                    with torch.no_grad():
                        output = model(batch_x)
                else :
                    output = model(batch_x)
                pred = torch.argmax(output, -1)
                loss = criterion(output, batch_y)#Loss считаем на сыром output.Softmax уже в лоссе
                
                if phase == 'train':
                    loss.backward()
                    optimizer.step()
                
                # статистика для фазы
                running_loss += loss.item()
                running_f1 += multiclass_f1_score(pred, batch_y, num_classes=42).tolist()
                running_acc += int(torch.sum(pred == batch_y.data))
            #Подсчёт усреднённых Loss и F1 для фазы и добавление данных в историю 
            epoch_loss = running_loss / len(dataloaders[phase])
            epoch_f1 = running_f1 / len(dataloaders[phase])
            epoch_acc = running_acc / dataset_sizes[phase]
            losses[phase].append(epoch_loss)
            metrics[phase].append(epoch_f1)
            accs[phase].append(epoch_acc)
            
            pbar.set_description('{} Loss: {:.4f} F1: {:.4f} Acc: {:.4f}'.format(
                                    phase, epoch_loss, epoch_f1, epoch_acc
                                ))
            
            # если во время валидации на очередной эпохе словили наилучший усреднённый f1
            # то сохраним его в best_f1 и сохраняем веса этой модели в best_model_wts
            if phase == 'val' and epoch_f1 > best_f1:
                best_f1 = epoch_f1
                best_model_wts = model.state_dict()
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc  
    #=====Вывод технической информации о времени работы======
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
         time_elapsed // 60, time_elapsed % 60))
    print('Best val F!: {:4f}'.format(best_f1))
    print('Best val Acc: {:4f}'.format(best_acc))
    
    # загрузим лучшие веса модели
    #model.load_state_dict(best_model_wts)
    return model, losses, metrics, accs, best_model_wts


# Функция визуализации работы модели
def visualize_model(model, num_images=6):
    images_so_far = 0
    fig = plt.figure()

    for i, data in enumerate(dataloaders['val']):
        inputs, labels = data
        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)

        outputs = model(inputs)
        _, preds = torch.max(outputs.data, 1)

        for j in range(inputs.size()[0]):
            images_so_far += 1
            ax = plt.subplot(num_images // 2, 2, images_so_far)
            ax.axis('off')
            ax.set_title('predicted: {}'.format(class_names[preds[j]]))
            imshow(inputs.cpu().data[j])

            if images_so_far == num_images:
                return
            
# Оценка качества модели на val сете
def evaluate(model,batch):
    
    # Создаём loader,в который засовывем классы.Далее при выплёвывании батча он будет 
    # обращаться к классу через _getitem_ и брать оттуда предобработанные тензоры с их лейблами
    dataloaders = {'train': torch.utils.data.DataLoader(train_dataset, batch_size=batch,
                                              shuffle=True, num_workers=2),
               'val': torch.utils.data.DataLoader(val_dataset, batch_size=batch,
                                              shuffle=True, num_workers=2)}    
    model.eval()
    
    runninig_f1 = 0
    for data in dataloaders['val']:
        
        batch_x, batch_y = data
        
        if device == 'cuda' :
            batch_x = batch_x.cuda()
            batch_y = batch_y.cuda()
            
        # forard pass
        output = model(batch_x)
        pred = torch.argmax(output, -1)
        
        runninig_f1 += multiclass_f1_score(pred, batch_y, num_classes=42).tolist()
        
    return runninig_f1 / len(dataloaders['val'])

# %% [markdown]
# # AlexNet

# %%
model = models.alexnet(weights='AlexNet_Weights.DEFAULT')
model
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
# ...

# %%
# num_features -- это размерность вектора фичей, поступающего на вход в FC слой
num_features = 4096
# Заменяем Output слой на наш линейный классификатор
model.classifier[6] = nn.Linear(num_features, len(set(train_dataset.labels)) )

# Использовать ли GPU
if device == 'cuda':
    model = model.cuda()

# В качестве loss function используем кросс-энтропию
loss_fn = nn.CrossEntropyLoss()

# В качестве оптимизатора - Adam
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# Умножает learning_rate на 0.1 каждые 7 эпох (это одна из эвристик, не было на лекциях)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

alex_losses = {'train': [], "val": []}
alex_f1 = {'train': [], "val": []}
alex_acc = {'train': [], "val": []}

# %%
alex, alex_losses, alex_f1, alex_acc, alex_best_wts= training(model, loss_fn,
                                      optimizer,
                                      exp_lr_scheduler,
                                      num_epochs=10, batch = 500, 
                                      losses=alex_losses, metrics=alex_f1, accs=alex_acc )
# Out:
# ...
# val iter::   0%|          | 0/11 [00:00<?, ?it/s]
# Training complete in 8m 27s
# Best val F!: 0.878552
# Best val Acc: 0.878678

# %%
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(alex_losses['train'], label="train")
plt.plot(alex_losses['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(alex_f1['train'], label="train")
plt.plot(alex_f1['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(alex_acc['train'], label="train")
plt.plot(alex_acc['val'], label="val")
plt.legend()
plt.show()

# %%
torch.save(model.state_dict(), 'AlexNet_fine_tune.pth') # Cохраняем полученные веса на HDD
model.load_state_dict(torch.load('AlexNet_fine_tune.pth')) #Убедимся что мы всё сохранили

# %%
print("Accuracy: {0:.4f}".format(evaluate(model)))

# %% [markdown]
# # VGG 16

# %%
model = models.vgg16_bn(weights='VGG16_BN_Weights.IMAGENET1K_V1')

# %%
num_features = 4096
# Заменяем Fully-Connected слой на наш линейный классификатор
model.classifier[6] = nn.Linear(num_features, len(set(train_dataset.labels)) )

# Использовать ли GPU
if device == 'cuda':
    model = model.cuda()

# В качестве loss function используем кросс-энтропию
loss_fn = nn.CrossEntropyLoss()

# В качестве оптимизатора - Adam
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# Умножает learning_rate на 0.1 каждые 7 эпох (это одна из эвристик, не было на лекциях)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

vgg_losses = {'train': [], "val": []}
vgg_f1 = {'train': [], "val": []}
vgg_acc = {'train': [], "val": []}

# %%
vgg, vgg_losses, vgg_f1, vgg_acc, vgg_best_wts= training(model, loss_fn,
                                      optimizer,
                                      exp_lr_scheduler,
                                      num_epochs=20, batch = 65, 
                                      losses=vgg_losses, metrics=vgg_f1, accs=vgg_acc )

# %%
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(vgg_losses['train'], label="train")
plt.plot(vgg_losses['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(vgg_f1['train'], label="train")
plt.plot(vgg_f1['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(vgg_acc['train'], label="train")
plt.plot(vgg_acc['val'], label="val")
plt.legend()
plt.show()

# %%
torch.save(model.state_dict(), 'VGG_trained.pth') # Cохраняем полученные веса на HDD
model.load_state_dict(torch.load('VGG_trained.pth')) #Убедимся что мы всё сохранили

# %%
print("Accuracy: {0:.4f}".format(evaluate(model)))

# %% [markdown]
# # Fine Tune approach

# %% [markdown]
# ### AlexNet

# %%
model = models.alexnet(weights='AlexNet_Weights.DEFAULT')

# %%
model.classifier
# Out:
# Sequential(
#   (0): Dropout(p=0.5, inplace=False)
#   (1): Linear(in_features=9216, out_features=4096, bias=True)
#   (2): ReLU(inplace=True)
#   (3): Dropout(p=0.5, inplace=False)
#   (4): Linear(in_features=4096, out_features=4096, bias=True)
#   (5): ReLU(inplace=True)
#   (6): Linear(in_features=4096, out_features=42, bias=True)
# )

# %%
num_features = 4096
model.classifier[6] = nn.Linear(num_features, 42)

model = model.to(device)

loss_fn = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

alex_fe_losses = {'train': [], "val": []}
alex_fe_f1 = {'train': [], "val": []}
alex_fe_acc = {'train': [], "val": []}

# %%
alex_fe, alex_fe_losses, alex_fe_f1, alex_fe_acc, alex_fe_best_wts= training(model, loss_fn,
                                      optimizer,
                                      exp_lr_scheduler,
                                      num_epochs=20, batch = 128, 
                                      losses=alex_fe_losses, metrics=alex_fe_f1, accs=alex_fe_acc )
# Out:
# Epoch::   0%|          | 0/20 [00:00<?, ?it/s]
# /home/daniil/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# ...
# val iter::   0%|          | 0/41 [00:00<?, ?it/s]
# Training complete in 12m 53s
# Best val F!: 0.935859
# Best val Acc: 0.935804

# %%
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(alex_fe_losses['train'], label="train")
plt.plot(alex_fe_losses['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(alex_fe_f1['train'], label="train")
plt.plot(alex_fe_f1['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(alex_fe_acc['train'], label="train")
plt.plot(alex_fe_acc['val'], label="val")
plt.legend()
plt.show()

# %%
torch.save(model.state_dict(), 'AlexNet_pretrained(93.4).pth') # Cохраняем полученные веса на HDD
model.load_state_dict(torch.load('AlexNet_pretrained(93.4).pth'))
# Out:
# <All keys matched successfully>

# %%
print("Accuracy: {0:.4f}".format(evaluate(model,128)))
# Out:
# Accuracy: 0.9347

# %% [markdown]
# # Feature Extractor approach

# %% [markdown]
# ### VGG 16

# %%
model = models.vgg19_bn(weights='VGG19_BN_Weights.DEFAULT')

# %%
for param in model.parameters():
    param.requires_grad = False

# %%
model.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=25088, out_features=4096, bias=True)
#   (1): ReLU(inplace=True)
#   (2): Dropout(p=0.5, inplace=False)
#   (3): Linear(in_features=4096, out_features=4096, bias=True)
#   (4): ReLU(inplace=True)
#   (5): Dropout(p=0.5, inplace=False)
#   (6): Linear(in_features=4096, out_features=1000, bias=True)
# )

# %%
model.classifier[0] = nn.Linear(in_features=25088, out_features=4096, bias=True)
model.classifier[1] = nn.ReLU(inplace=True)
model.classifier[2] = nn.Dropout(p=0.5, inplace=False)
model.classifier[3] = nn.Linear(in_features=4096, out_features=4096, bias=True)
model.classifier[4] = nn.ReLU(inplace=True)
model.classifier[5] = nn.Dropout(p=0.5, inplace=False)
model.classifier[6] = nn.Linear(in_features=4096, out_features=42, bias=True)

model = model.to(device)

loss_fn = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

vgg_fe_losses = {'train': [], "val": []}
vgg_fe_f1 = {'train': [], "val": []}
vgg_fe_acc = {'train': [], "val": []}

# %%
vgg_fe, vgg_fe_losses, vgg_fe_f1, vgg_fe_acc, vgg_fe_best_wts= training(model, loss_fn,
                                      optimizer,
                                      exp_lr_scheduler,
                                      num_epochs=20, batch = 50, 
                                      losses=vgg_fe_losses, metrics=vgg_fe_f1, accs=vgg_fe_acc )
# Out:
# Epoch::   0%|          | 0/20 [00:00<?, ?it/s]
# /home/daniil/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# ...
# val iter::   0%|          | 0/105 [00:00<?, ?it/s]
# Training complete in 77m 40s
# Best val F!: 0.865154
# Best val Acc: 0.865304

# %%
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(vgg_fe_losses['train'], label="train")
plt.plot(vgg_fe_losses['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(vgg_fe_f1['train'], label="train")
plt.plot(vgg_fe_f1['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(vgg_fe_acc['train'], label="train")
plt.plot(vgg_fe_acc['val'], label="val")
plt.legend()
plt.show()

# %% [markdown]
# # Дообучение ResNet, предобученной на IMAGENET

# %% [markdown]
#  ![alt text](https://s1.hostingkartinok.com/uploads/images/2023/11/5adae1b02f50b86522dc3e25fc9ccff0.jpg)

# %%
model = models.resnet152(weights='ResNet152_Weights.DEFAULT')

# %%
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
# ...

# %%
model.fc = nn.Linear(in_features=2048, out_features=42, bias=True)

# %%
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

resnet152_fe_losses = {'train': [], "val": []}
resnet152_fe_f1 = {'train': [], "val": []}
resnet152_fe_acc = {'train': [], "val": []}

# %%
resnet152_fe, resnet152_fe_losses, resnet152_fe_f1, resnet152_fe_acc, resnet152_fe_best_wts= training(
                                      model, 
                                      loss_fn,
                                      optimizer,
                                      exp_lr_scheduler,
                                      num_epochs=10, batch = 60, 
                                      losses=resnet152_fe_losses,
                                      metrics=resnet152_fe_f1, 
                                      accs=resnet152_fe_acc )
# Out:
# Epoch::   0%|          | 0/10 [00:00<?, ?it/s]
# /home/daniil/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# ...
# val iter::   0%|          | 0/88 [00:00<?, ?it/s]
# Training complete in 42m 44s
# Best val F!: 0.981250
# Best val Acc: 0.981085

# %%
torch.save(model.state_dict(), 'ResNet152_pretrained(93.4).pth') # Cохраняем полученные веса на HDD
model.load_state_dict(torch.load('ResNet152_pretrained(93.4).pth'))
# Out:
# <All keys matched successfully>

# %%
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(resnet152_fe_losses['train'], label="train")
plt.plot(resnet152_fe_losses['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(resnet152_fe_f1['train'], label="train")
plt.plot(resnet152_fe_f1['val'], label="val")
plt.legend()
plt.show()

# %% [markdown]
# # Inception V3 Pretrained

# %% [markdown]
# ### Fine Tune approach

# %% [markdown]
# <!-- def IncV3_training(model, criterion, optimizer, scheduler, num_epochs, batch, losses, metrics, accs):
#
#     # Создаём loader,в который засовывем классы.Далее при выплёвывании батча он будет
#     # обращаться к классу через _getitem_ и брать оттуда предобработанные тензоры с их лейблами
#     dataloaders = {'train': torch.utils.data.DataLoader(train_dataset, batch_size=batch,
#                                               shuffle=True, num_workers=2),
#                'val': torch.utils.data.DataLoader(val_dataset, batch_size=batch,
#                                               shuffle=True, num_workers=2)}
#
#     since = time.time()
#     best_model_wts = model.state_dict()
#     best_f1 = 0
#     best_acc = 0
#
#     pbar = trange(num_epochs, desc="Epoch:")
#
#     for epoch in pbar:
#         for phase in ['train', 'val']:
#             #=====Установка режима работы модели в зав-ти от фазы======
#             if phase == 'train':
#                 scheduler.step()
#                 model.train(True)
#             else:
#                 model.eval()
#             #======Обновление loss и целевых метрик =============
#             running_loss = 0.0
#             running_f1 = 0
#             running_acc = 0
#             #======Процесс итерации по батчам ===================
#             for data in tqdm(dataloaders[phase], leave=False, desc=f"{phase} iter:"):
#
#                 batch_x, batch_y = data
#
#                 if device == 'cuda':
#                     batch_x = batch_x.cuda()
#                     batch_y = batch_y.cuda()
#                 else:
#                     batch_x, batch_y = batch_x, batch_y
#
#                 if phase == "train":
#                     optimizer.zero_grad()
#
#                 if phase == "val":
#                     with torch.no_grad():
#                         output = model(batch_x)
#                 else :
#                     output = model(batch_x)
#                 pred = torch.argmax(output.logits, -1)
#                 loss = criterion(output.logits, batch_y)#Loss считаем на сыром output.Softmax уже в лоссе
#
#                 if phase == 'train':
#                     loss.backward()
#                     optimizer.step()
#
#                 # статистика для фазы
#                 running_loss += loss.item()
#                 running_f1 += multiclass_f1_score(pred, batch_y, num_classes=42).tolist()
#                 running_acc += int(torch.sum(pred == batch_y.data))
#             #Подсчёт усреднённых Loss и F1 для фазы и добавление данных в историю
#             epoch_loss = running_loss / len(dataloaders[phase])
#             epoch_f1 = running_f1 / len(dataloaders[phase])
#             epoch_acc = running_acc / dataset_sizes[phase]
#             losses[phase].append(epoch_loss)
#             metrics[phase].append(epoch_f1)
#             accs[phase].append(epoch_acc)
#
#             pbar.set_description('{} Loss: {:.4f} F1: {:.4f} Acc: {:.4f}'.format(
#                                     phase, epoch_loss, epoch_f1, epoch_acc
#                                 ))
#
#             # если во время валидации на очередной эпохе словили наилучший усреднённый f1
#             # то сохраним его в best_f1 и сохраняем веса этой модели в best_model_wts
#             if phase == 'val' and epoch_f1 > best_f1:
#                 best_f1 = epoch_f1
#                 best_model_wts = model.state_dict()
#             if phase == 'val' and epoch_acc > best_acc:
#                 best_acc = epoch_acc
#     #=====Вывод технической информации о времени работы======
#     time_elapsed = time.time() - since
#     print('Training complete in {:.0f}m {:.0f}s'.format(
#          time_elapsed // 60, time_elapsed % 60))
#     print('Best val F!: {:4f}'.format(best_f1))
#     print('Best val Acc: {:4f}'.format(best_acc))
#
#     # загрузим лучшие веса модели
#     #model.load_state_dict(best_model_wts)
#     return model, losses, metrics, accs, best_model_wts
#
#
# # Оценка качества модели на val сете
# def IncV3_evaluate(model,batch):
#
#     # Создаём loader,в который засовывем классы.Далее при выплёвывании батча он будет
#     # обращаться к классу через _getitem_ и брать оттуда предобработанные тензоры с их лейблами
#     dataloaders = {'train': torch.utils.data.DataLoader(train_dataset, batch_size=batch,
#                                               shuffle=True, num_workers=2),
#                'val': torch.utils.data.DataLoader(val_dataset, batch_size=batch,
#                                               shuffle=True, num_workers=2)}
#     model.eval()
#
#     runninig_f1 = 0
#     for data in dataloaders['val']:
#
#         batch_x, batch_y = data
#
#         if device == 'cuda' :
#             batch_x = batch_x.cuda()
#             batch_y = batch_y.cuda()
#
#         # forard pass
#         output = model(batch_x)
#         pred = torch.argmax(output.logits, -1)
#
#         runninig_f1 += multiclass_f1_score(pred, batch_y, num_classes=42).tolist()
#
#     return runninig_f1 / len(dataloaders['val']) -->

# %%
model = models.inception_v3(weights='IMAGENET1K_V1')

# %%
RESCALE_SIZE = 299
model.fc = nn.Linear(in_features=2048, out_features=42, bias=True)
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

incv3_losses = {'train': [], "val": []}
incv3_f1 = {'train': [], "val": []}
incv3_acc = {'train': [], "val": []}

# %%
incv3, incv3_losses, incv3_f1, incv3_acc, incv3_best_wts= IncV3_training(
                                      model, 
                                      loss_fn,
                                      optimizer,
                                      exp_lr_scheduler,
                                      num_epochs=10, batch = 70, 
                                      losses=incv3_losses,
                                      metrics=incv3_f1, 
                                      accs=incv3_acc )

# %% [markdown]
# # GoogleNet

# %%
model = models.googlenet(weights='GoogLeNet_Weights.IMAGENET1K_V1')

# %%
model.fc = nn.Linear(in_features=1024, out_features=42, bias=True)

# %%
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

inc_losses = {'train': [], "val": []}
inc_f1 = {'train': [], "val": []}
inc_acc = {'train': [], "val": []}

# %%
inc, inc_losses, inc_f1, inc_acc, inc_best_wts= training(
                                      model, 
                                      loss_fn,
                                      optimizer,
                                      exp_lr_scheduler,
                                      num_epochs=10, batch = 150, 
                                      losses=inc_losses,
                                      metrics=inc_f1, 
                                      accs=inc_acc )
# Out:
# Epoch::   0%|          | 0/10 [00:00<?, ?it/s]
# /home/daniil/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# ...
# val iter::   0%|          | 0/35 [00:00<?, ?it/s]
# Training complete in 9m 19s
# Best val F!: 0.959460
# Best val Acc: 0.959496

# %%
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(inc_losses['train'], label="train")
plt.plot(inc_losses['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(inc_f1['train'], label="train")
plt.plot(inc_f1['val'], label="val")
plt.legend()

# %% [markdown]
# # DenceNet 201

# %%
model = models.densenet201(weights='IMAGENET1K_V1')
# Out:
# Downloading: "https://download.pytorch.org/models/densenet201-c1103571.pth" to /home/daniil/.cache/torch/hub/checkpoints/densenet201-c1103571.pth
# 100%|██████████████████████████████████████| 77.4M/77.4M [00:06<00:00, 11.6MB/s]

# %%
model.classifier = nn.Linear(in_features=1920, out_features=42, bias=True)

# %%
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

dense_losses = {'train': [], "val": []}
dense_f1 = {'train': [], "val": []}
dense_acc = {'train': [], "val": []}

# %%
dense, dense_losses, dense_f1, dense_acc, inc_best_wts= training(
                                      model, 
                                      loss_fn,
                                      optimizer,
                                      exp_lr_scheduler,
                                      num_epochs=10, batch = 50, 
                                      losses=dense_losses,
                                      metrics=dense_f1, 
                                      accs=dense_acc )
# Out:
# Epoch::   0%|          | 0/10 [00:00<?, ?it/s]
# /home/daniil/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# ...
# val iter::   0%|          | 0/105 [00:00<?, ?it/s]
# Training complete in 31m 15s
# Best val F!: 0.982006
# Best val Acc: 0.982041

# %%
torch.save(model.state_dict(), 'DenseNet_pretrained(98).pth')
model.load_state_dict(torch.load('DenseNet_pretrained(98).pth'))
# Out:
# <All keys matched successfully>

# %%
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(dense_losses['train'], label="train")
plt.plot(dense_losses['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(dense_f1['train'], label="train")
plt.plot(dense_f1['val'], label="val")
plt.legend()
plt.show()

# %% [markdown]
# # ResNeXt101(64x4d)

# %%
model = models.resnext101_64x4d(weights='IMAGENET1K_V1')

# %%
model.fc = nn.Linear(in_features=2048, out_features=42, bias=True)

# %%
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

resnext_losses = {'train': [], "val": []}
resnext_f1 = {'train': [], "val": []}
resnext_acc = {'train': [], "val": []}

# %%
resnext, resnext_losses, resnext_f1, resnext_acc, resnext_best_wts= training(
                                      model, 
                                      loss_fn,
                                      optimizer,
                                      exp_lr_scheduler,
                                      num_epochs=6, batch = 40, 
                                      losses=resnext_losses,
                                      metrics=resnext_f1, 
                                      accs=resnext_acc )
# Out:
# Epoch::   0%|          | 0/6 [00:00<?, ?it/s]
# /home/daniil/anaconda3/lib/python3.11/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# ...
# val iter::   0%|          | 0/131 [00:00<?, ?it/s]
# Training complete in 39m 16s
# Best val F!: 0.977290
# Best val Acc: 0.977264

# %%
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(resnext_losses['train'], label="train")
plt.plot(resnext_losses['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(resnext_f1['train'], label="train")
plt.plot(resnext_f1['val'], label="val")
plt.legend()
plt.show()

# %%
torch.save(model.state_dict(), 'ResNeXt101_pretrained(97.7).pth')
model.load_state_dict(torch.load('ResNeXt101_pretrained(97.7).pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Custom CNN

# %%
# Функцмя воспроизводимости результата
def set_seed(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    np.random.seed(seed)
    random.seed(seed)

# Установим значение равное 117 
set_seed(117)

# %%
# Очень простая сеть
class CustomCNN(nn.Module):
    
    def __init__(self, n_classes):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3),           
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.bn1 = nn.BatchNorm2d(8)
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3),            
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.bn2 = nn.BatchNorm2d(16)
        self.conv3 = nn.Sequential(
            nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3),            
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.bn3 = nn.BatchNorm2d(32)
        self.conv4 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3),            
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.bn4 = nn.BatchNorm2d(64)
        self.conv5 = nn.Sequential(
            nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3),            
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2)
        )
        self.bn5 = nn.BatchNorm2d(96)
        self.dropout = nn.Dropout(p=0.3)
        self.out = nn.Linear(96 * 5 * 5, n_classes)
  

    def forward(self, x):
        x = self.bn1(self.conv1(x))
        x = self.bn2(self.conv2(x))
        x = self.bn3(self.conv3(x))
        x = self.bn4(self.conv4(x))
        x = self.dropout(self.bn5(self.conv5(x)))

        x = x.view(x.size(0), -1)
        logits = self.out(x)
        return logits

# %%
model = CustomCNN(n_classes=42)
model = model.to(device)

loss_fn = nn.CrossEntropyLoss()

optimizer = optim.Adam(model.parameters(), lr=1e-4)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

custom_losses = {'train': [], "val": []}
custom_f1 = {'train': [], "val": []}
custom_acc = {'train': [], "val": []}

# %%
custom, custom_losses, custom_f1, custom_acc, custom_best_wts= training(
                                      model, 
                                      loss_fn,
                                      optimizer,
                                      exp_lr_scheduler,
                                      num_epochs=10, batch = 150, 
                                      losses=custom_losses,
                                      metrics=custom_f1, 
                                      accs=custom_acc )
# Out:
# ...
# val iter::   0%|          | 0/35 [00:00<?, ?it/s]
# Training complete in 5m 6s
# Best val F!: 0.656995
# Best val Acc: 0.656859

# %%
import seaborn as sns

sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(custom_losses['train'], label="train")
plt.plot(custom_losses['val'], label="val")
plt.legend()
plt.show()

# %%
sns.set(style="whitegrid", font_scale=1.4)

# Построим график лосса при обучении и валидации

#Ваш код здесь
plt.figure(figsize=(12, 8))
plt.plot(custom_f1['train'], label="train")
plt.plot(custom_f1['val'], label="val")
plt.legend()
plt.show()
